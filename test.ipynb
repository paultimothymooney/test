# %% [markdown]
# <a href="https://kaggle.com/code/welcome?src=https://github.com/paultimothymooney/test/blob/master/test.ipynb" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
print('hello world')
# Out:
# hello world
